# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is DC48-E080
#
#  Directory of C:\Users\abdno\Jupiter\exploring
#
# 10/08/2024  12:26 PM    <DIR>          .
# 10/08/2024  12:21 PM    <DIR>          ..
# 10/08/2024  12:26 PM    <DIR>          .ipynb_checkpoints
# 10/08/2024  12:23 PM                10 cd
# 10/07/2024  06:45 AM           250,754 etex.jpeg
# 10/08/2024  12:26 PM                72 Untitled.ipynb
#                3 File(s)        250,836 bytes
#                3 Dir(s)  44,539,125,760 bytes free

# %%
from skimage import io
from matplotlib import pyplot as plt

img = io.imread("./etex.jpeg", as_gray=True)
plt.imshow(img, cmap='gray')
plt.show()
